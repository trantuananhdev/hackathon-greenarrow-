# %%
from load_dataset import load_dataset
import json

from pathlib import Path

# %%
frame, manifest = load_dataset("reference/dien_bien_locations.parquet")
print(f"Loaded {len(frame)} rows from {Path('reference/dien_bien_locations.parquet')}")
if manifest is not None:
    print(json.dumps(manifest, ensure_ascii=False, indent=2))
# Out:
# Loaded 85 rows from reference\dien_bien_locations.parquet

# %%
frame
# Out:
#           location_id   province           old_admin_unit  \
# 0   41894480814245531  Điện Biên       Phường Mường Thanh
# 1   18263379520017300  Điện Biên         Phường Tân Thanh
# 2   47583508398538892  Điện Biên           Phường Him Lam
# 3   43226953543943747  Điện Biên        Phường Thanh Bình
# 4   11179862286177994  Điện Biên      Phường Thanh Trường
# ..                ...        ...                      ...
# 80  16490784013864026  Điện Biên  Thị trấn Điện Biên Đông
# 81  15130609815856258  Điện Biên                Xã Na Son
# 82  34632733481381832  Điện Biên               Xã Keo Lôm
# 83  46334540729225135  Điện Biên               Xã Xa Dung
# 84  43034779169832108  Điện Biên               Xã Phì Nhừ
#
#           new_admin_unit  latitude  longitude  \
# 0   Phường Điện Biên Phủ   21.3854   103.0189
# 1   Phường Điện Biên Phủ   21.3923   103.0165
# 2   Phường Điện Biên Phủ   21.4031   103.0248
# 3   Phường Điện Biên Phủ   21.3911   102.9995
# ...

# %%
manifest
